# %%
# 함수 만들기

def hello():
    print("Hello world!")

# %%
hello()
# Out:
# Hello world!

# %%
# 함수의 실행 순서

# hello2()  -> 오류 발생 / 함수를 작성을 먼저 한 후 호출해야함

# def hello2():
#     pinrt("Hello world!")

# %%
# 덧셈 함수 만들기

def add(a, b):
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
# 함수 독스트링 사용하기

def add(a, b):
    """
    매개변수
    a: int
    b: int
    
    출력: int
    """
    print(a + b)
