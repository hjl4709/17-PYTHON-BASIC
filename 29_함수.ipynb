# %%
# 함수 만들기

def hello():
    print("Hello world!")

# %%
hello()
# Out:
# Hello world!

# %%
# 함수의 실행 순서

# hello2()  -> 오류 발생 / 함수를 작성을 먼저 한 후 호출해야함

# def hello2():
#     pinrt("Hello world!")

# %%
# 덧셈 함수 만들기

def add(a, b):
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
# 함수 독스트링 사용하기

def add(a, b):
    """
    매개변수
    a: int
    b: int
    
    출력: int
    """
    print(a + b)

# %%
# 함수의 결과를 반환하기
# def add(a, b):
#     print(a + b)
#     return None

def add(a, b):
    return a + b

# %%
x = add(10, 20)
print(x)
# Out:
# 30

# %%
def add2(a, b):
    print(a + b)
    return

# %%
y = add2(10, 20)
print(y)
# Out:
# 30
# None

# %%
# 함수에서 값을 여러 개 반환하기

def add_sub(a, b):
    return a + b, a - b

x, y = add_sub(10, 20)
print(x)
print(y)

z = add_sub(10, 20)
print(z)
# Out:
# 30
# -10
# (30, -10)

# %%
def add_sub(a, b):
    return a + b 
    return a - b # 실행되지 않음 / return을 만나면 함수가 종료되기 때문에 return은 하나만 있어야함

# %%
# 함수의 호출 과정 알아보기

def mul(a, b):
    c = a * b
    return c

def add(a, b):
    c = a  + b
    print(c)
    d = mul(a , b)
    print(d)

x = 10
y = 20
add(x, y)
# Out:
# 30
# 200

# %%
# 29.6 퀴즈
# 1. c
# 2. d
# 3. a, c, d

# %%
# 29.7 연습문제: 몫과 나머지를 구하는 함수 만들기
x = 10
y = 3

def get_quotient_remainder(a, b):
    return a // b, a % b

quotient, remainder = get_quotient_remainder(x, y)
print('몫 : {0}, 나머지: {1}'.format(quotient, remainder))
# Out:
# 몫 : 3, 나머지: 1

# %%
# 29.8 심사문제: 사칙 연산 함수 만들기

x, y = map(int,input().split())

def calc(a, b):
    return a + b, a - b, a * b, a / b

a, s, m, d = calc(x, y)
print('덧셈: {0}, 뺄셈: {1}, 곱셈: {2}, 나눗셈: {3}'.format(a, s, m, d))
# Out:
# 덧셈: 48, 뺄셈: 32, 곱셈: 320, 나눗셈: 5.0
