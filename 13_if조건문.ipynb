# %%
# if 조건문 사용하기

x= 10
if x == 10:
    print('10입니다.')
# Out:
# 10입니다.

# %%
# if 조건문에서 코드를 생략하기
x = 10
if x == 10:
    pass

# %%
# if 조건문과 들여쓰기
x = 10
if x == 10:
    print("x에 들어가는 숫자는")
        # print("10입니다.") -> 아무 의미 없는 들여쓰기는 오류
# Out:
# x에 들어가는 숫자는

# %%
x = 10
if x == 10:
    print("x에 들어가는 숫자는")
print("10입니다.") # -> if 제어문에 속하는 문장이 아니기 때문에 정상적으로 출력됨. but if와는 상관이 없음
# Out:
# x에 들어가는 숫자는
# 10입니다.

# %%
# 중첩 if 조건문 사용하기 -> elif가 있기 때문에 사용할 일이 많지는 않음

x = 15

if x >= 10:
    print("10 이상입니다.")
    if x == 15:
        print("15 입니다.")
    if x == 20:
        print("20 입니다..")
# Out:
# 10 이상입니다.
# 15 입니다.

# %%
x = int(input())

if x == 10:
    print('10 입니다.')
if x == 20:
    print('20 입니다.')
# Out:
# 10 입니다.

# %%
# 13.5 퀴즈
# 1. c
# 2. c, j
# 3. a

# %%
# 13.6 연습문제: if 조건문 사용하기

x = 5

if x != 10:
    print("ok")
# Out:
# ok

# %%
# 13.7 심사문제: 온라인 할인 쿠폰 시스템 만들기

x = int(input())
coupon = input()

if coupon == "Cash3000":
    print(x - 3000)
if coupon == "Cash5000":
    print(x - 5000)
# Out:
# 24000

# %%
x = int(input())
coupon = input()

if coupon == "Cash3000":
    print(x - 3000)
if coupon == "Cash5000":
    print(x - 5000)
# Out:
# 67000
