# %%
# 문자열 조작하기
## 문자열 바꾸기

a = "Hello, world".replace("world", "Python")
print(a)
# Out:
# Hello, Python

# %%
## 문자 바꾸기

table = str.maketrans("aeiou","12345")
"apple".translate(table)
# Out:
# '1ppl2'

# %%
## 문자열 분리하기

text = "apple pear grape pineapple orange"
text.split()
# Out:
# ['apple', 'pear', 'grape', 'pineapple', 'orange']

# %%
text = "apple, pear, grape, pineapple, orange"
text.split(",")
# Out:
# ['apple', ' pear', ' grape', ' pineapple', ' orange']

# %%
## 구분자 문자열과 문자열 리스트 연결하기
lis = ['apple', ' pear', ' grape', ' pineapple', ' orange']

"-".join(lis)
# Out:
# 'apple- pear- grape- pineapple- orange'

# %%
## 소문자를 대문자로, 대문자를 소문자로
"python". upper()
# Out:
# 'PYTHON'

# %%
'PYTHON'.lower()
# Out:
# 'python'

# %%
"   python  ". strip()
# Out:
# 'python'

# %%
## 특정 문자 삭제하기
", !python.!".strip(",.! ") # -> strip은 양 끝에 있는 것만 지움!
# Out:
# 'python'

# %%
## 문자열을 왼쪽 정렬하기
"python".rjust(10)
# Out:
# '    python'

# %%
## 문자열을 가운데 정렬하기
"python".center(10)
# Out:
# '  python  '

# %%
## 매서드 체이닝
"python".rjust(10).upper().strip()
# Out:
# 'PYTHON'

# %%
## 문자열 왼쪽에 0 채우기
print("35".zfill(4))
print("3.5".zfill(6))
# Out:
# 0035
# 0003.5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 5
#       1 ## 문자열 왼쪽에 0 채우기
#       2 print("35".zfill(4))
#       3 print("3.5".zfill(6))
#       4 x = [1, 2, 3, 4]
# ----> 5 print("hello {0},{1},{2},{3}".format(x))
#
# IndexError: Replacement index 1 out of range for positional args tuple

# %%
## 문자열 위치 찾기
"apple pineapple".find('pl')
# Out:
# 2

# %%
"apple pineapple".rfind('pl')
# Out:
# 12

# %%
# 문자열 서식 지정자와 포메팅 사용하기

# %%
## 서식 지정자로 소수점 표현하기
# "%f" % 숫자

"%f" % 2.3
# Out:
# '2.300000'

# %%
# "%.자릿수f" % 숫자
"%.1f" % 2.3
# Out:
# '2.3'

# %%
"%10.3f" % 2.3
# Out:
# '     2.300'

# %%
## 서식지정자로 문자열 정렬하기
print("%10s" % 'python')
print("%-10s" % "python")
# Out:
#     python
# python

# %%
## 서식지정자로 문자열 안에 값 여러개 넣기
"Today is %d %s" % (3, "April")
# Out:
# 'Today is 3 April'

# %%
## format 매서드 사용하기
"hello {0}".format('python')
# Out:
# 'hello python'

# %%
"Hello {language} {version}".format(language="Python",version="3.14.6")
# Out:
# 'Hello Python 3.14.6'

# %%
## format 매서드로 문자열 정렬하기
print('{0:<10}'.format('phython'))
print('{0:>10}'.format('phython'))
print('{:>10}'.format('phython'))
# Out:
# phython
#    phython
#    phython

# %%
## 숫자 개수 맞추기
print('%03d' % 1)
print('{0:03d}'.format(35))
print('%08.2f' % 3.6)
print('{0:03.2f}'.format(3.6))
print('{0:08.2f}'.format(150.37))
# Out:
# 001
# 035
# 00003.60
# 3.60
# 00150.37

# %%
# 24.3 퀴즈
# 1. a, e
# 2. d
# 3. b, d
# 4. c, d

# %%
# 24.4 연습문제
path = 'C:\\Users\\dojang\\Appdata\\Local\\Programs\\Python\\Python36-32\\python.exe'
a = path.split("\\")
filename = a[-1]

print(filename)
# Out:
# python.exe

# %%
# 24.5 심사문제: 특정 단어 개수 세기
# the grown-ups' response, this time, was to advise to me to lay aside my drawings of boa constrictors, whether from the inside or the outside, and devote myself instead to geograhy, history, arithmetic, and grammar. That is why, at the, age of six, I gave up what might have been a magnificent career as a painter. I had been disheartened by the failure of my Drawing Number One and my Drawing Number Two. Grown-ups never understand anything by themselves, and it is tiresome for children to be always and forever explaining things to the.
a = input()
a_2 = a.replace(",", " ").replace(".", " ")
a_3 = a_2.split()
print(a_3.count("the"))
# Out:
# 6

# %%
a = "the grown-ups' response, this time, was to advise to me to lay aside my drawings of boa constrictors, whether from the inside or the outside, and devote myself instead to geograhy, history, arithmetic, and grammar."
a.count("the")
.split('.') a.count("the")
# Out:
# 4

# %%
# 24. 6 심사문제: 높은 가격 순으로 출력하기
# 51900;83000;158000;367500;250000;59200;128500;1304000

price = list(map(int, input().split(";")))
price.sort(reverse=True)

for p in price:
    print('{:>9,}'.format(p))
# Out:
# 1,304,000
#   367,500
#   250,000
#   158,000
#   128,500
#    83,000
#    59,200
#    51,900
