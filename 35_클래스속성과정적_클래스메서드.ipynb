# %%
# 클래스 속성 사용하기

# class 클래스이름:
#     속성 = 값

class Person:
    bag = []

    def put_bag(self, stuff):
        self.bag.append(stuff)

james = Person()
james.put_bag("책")

maria = Person()
maria.put_bag("열쇠")

print(james.bag)
print(maria.bag)
# Out:
# ['책', '열쇠']
# ['책', '열쇠']

# %%
print(Person.bag)
# Out:
# ['책', '열쇠']

# %%
## 인스턴스 속성 사용하기

class Person:
    def __init__(self):
        self.bag = []

    def put_bag(self, stuff):
        self.bag.append(stuff)
    
james = Person()
james.put_bag("책")

maria = Person()
maria.put_bag("열쇠")

print(james.bag)
print(maria.bag)
# Out:
# ['책']
# ['열쇠']

# %%
## 비공개 클래스 속성 사용하기

class Knight:
    __item_limit = 10        # __@@_limit <- 비공개 클래스
    
    def print_item_limit(self):
        print(Knight.__item_limit)

x = Knight()
x.print_item_limit()

print(Knight.__item_limit)
# Out:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 12
#       8
#       9 x = Knight()
#      10 x.print_item_limit()
#      11
# ---> 12 print(Knight.__item_limit)
#
# AttributeError: type object 'Knight' has no attribute '__item_limit'

# %%
## 정적 메서드 사용하기

# class 클래스이름:
#     @staticmethod
#     def 메서드(매개변수1, 매개변수2):
#         코드

class Calc:
    @staticmethod
    def add(a, b):
        print(a + b)

    @staticmethod
    def mul(a,b):
        print(a * b)

Calc.add(10, 20)
Calc.mul(10,20)
# Out:
# 30
# 200

# %%
# 클래스 메서드 사용하기

# class 클래스이름:
#     @staticmethod
#     def 메서드(cls, 매개변수1, 매개변수2):
#         코드

class Person():
    count = 0

    def __init__(self):
        Person.count += 1


    @classmethod
    def print_count(cls):
        print(f"{cls.count}명 생성되었습니다.")


james = Person()
maria = Person()

Person.print_count()
# Out:
# 2명 생성되었습니다.

# %%
# 35.4 퀴즈
# 1.
# 2.
# 3.

# %%
# 35.5 연습문제: 날짜 클래스 만들기

class Date:
    @staticmethod
    def is_date_valid(date_string):
        year, month, day = map(int, date_string.split("-"))
        return month <= 12 and day >= 31
    
if Date.is_date_valid('2000-10-31'):
    print("올바른 날짜 형식입니다.")
else:
    print("잘못된 날짜 형식입니다.")
# Out:
# 올바른 날짜 형식입니다.

# %%
# 35.6 심사문제: 시간 클래스 만들기

class Time:
    def __init__(self, hour, minute, second):
        self.hour = hour
        self.minute = minute
        self.second = second
    
    @classmethod
    def from_string(cls, time_string):
        a, b, c = map(str, time_string.split(":"))
        return cls(a, b, c)


    @staticmethod
    def is_time_valid(time_string):
        hour, minute, second = map(int, time_string.split(":"))
        return hour <= 24 and minute <= 59 and second <= 60

time_string = input()

if Time.is_time_valid(time_string):
    t = Time.from_string(time_string)
    print(t.hour, t.minute, t.second)
else:
    print("잘못된 시간 형식입니다.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 22
#      18         return hour <= 24 and minute <= 59 and second <= 60
#      19
#      20 time_string = input()
#      21
# ---> 22 if Time.is_time_valid(time_string):
#      23     t = Time.from_string(time_string)
#      24     print(t.hour, t.minute, t.second)
#      25 else:
#
# Cell In[17], line 17, in Time.is_time_valid(time_string)
#      15     @staticmethod
#      16     def is_time_valid(time_string):
# ---> 17         hour, minute, second = map(int, time_string.split(":"))
#      18         return hour <= 24 and minute <= 59 and second <= 60
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# 35.6 심사문제: 시간 클래스 만들기

class Time:
    def __init__(self, hour, minute, second):
        self.hour = hour
        self.minute = minute
        self.second = second
    
    @classmethod
    def from_string(cls, time_string):
        a, b, c = map(str, time_string.split(":"))
        return cls(a, b, c)


    @staticmethod
    def is_time_valid(time_string):
        hour, minute, second = map(int, time_string.split(":"))
        return hour <= 24 and minute <= 59 and second <= 60

time_string = input()
Time.from_string(time_string).hour
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 21
#      17         hour, minute, second = map(int, time_string.split(":"))
#      18         return hour <= 24 and minute <= 59 and second <= 60
#      19
#      20 time_string = input()
# ---> 21 Time.from_string(time_string).hour
#
# Cell In[28], line 11, in Time.from_string(cls, time_string)
#       9     @classmethod
#      10     def from_string(cls, time_string):
# ---> 11         a, b, c = map(str, time_string.split(":"))
#      12         return cls(a, b, c)
#
# ValueError: not enough values to unpack (expected 3, got 1)
