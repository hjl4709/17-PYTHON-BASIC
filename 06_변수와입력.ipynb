# %%
# 변수 만들기
## 1. 영문문자, 숫자를 사용
## 2. 대소문자를 구분
## 3. 문자부터 시작을 해야하고, 숫자부터 시작 안됨 a1(O) 1a(X)
## 4. _(밑줄문자)로 시작할 수 있다.
## 5. 특수문자(+, -, *, /, %, ..)는 사용할 수 없음
## 6. 파이썬 키워드(if, for, while, print 등등)는 사용할 수 없음 -> 기본 함수의 원래 기능을 잃어버림

stand_alone = 1 # 파이썬에서 자주 사용 [스네이크 표기법]
StandAlone = 1 # 파이썬에서는 이러한 방식은 잘 사용하지 않음 [파스칼 표기법] 
standAlone = 1 # JAVA 같은 경우 사용.. 파이썬에서는 역시 잘 사용하지 않음 [카멜 표기법]
# stand-alone = 1 사용불가
# stand alone = 1 사용불가

# %%
# 변수 여러개를 한 번에 만들기

x, y, z = 10, 20, 30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
x = y = z = 10
print(x)
print(y)
print(z)
# Out:
# 10
# 10
# 10

# %%
x, y = 10, 20
x, y = y, x # 파이썬 코드의 편리함

print(x)
print(y)
# Out:
# 20
# 10

# %%
# 변수로 계산하기
a = 10
b = 20

a + b
# Out:
# 30

# %%
# 산술 연산 후 할당 연산자 사용하기
